# %% [markdown]
# # IMPORT

# %%
import os
import re
import time
import json
import asyncio
import numpy as np
import pandas as pd

from tqdm import tqdm
from googletrans import Translator

# %% [markdown]
# # FUNCTION

# %%
async def gg_translate(sentence, from_lang="vi", to_lang="en"):
    async with Translator() as translator:
        result = await translator.translate(sentence, src=from_lang, dest=to_lang)
        return result

async def run_gg_translate(sentence, from_lang="vi", to_lang="en"):
    translated_sentence_result = await gg_translate(sentence, from_lang=from_lang, to_lang=to_lang)
    return translated_sentence_result.text

# %%
async def row_translation(row_sentences, from_lang="vi", to_lang="en"):
    tasks = [run_gg_translate(sen) for sen in row_sentences]
    translated_sentences = await asyncio.gather(*tasks)
    return translated_sentences

# %% [markdown]
# # LOAD DATA

# %%
df_path = r"C:\APAC\all_projects\finetuning-airflow-project\projects\data\gather_all_contents.csv"
df = pd.read_csv(df_path)

# %% [markdown]
# # TRANSLATE

# %%
columns = df.columns
need_translated_columns = [
    col_name 
    for col_name in columns 
    if ("relative_sen" in col_name)
]

# %%
need_translated_df = df[need_translated_columns]
need_translated_values = need_translated_df.values

need_translated_columns = need_translated_df.columns
translated_columns = [f"translated_{col_name}" for col_name in need_translated_columns]
translated_data = {col_name: [] for col_name in translated_columns}

# %%
df.head()
df["Unnamed: 0"]
# Out:
# 0       9981
# 1       9980
# 2       9979
# 3       9978
# 4       9977
#         ...
# 9977       4
# 9978       3
# 9979       2
# 9980       1
# 9981       0
# Name: Unnamed: 0, Length: 9982, dtype: int64

# %%
save_path = r"C:\APAC\all_projects\finetuning-airflow-project\projects\data\save_translation\{id}.npy"
attempts = 3

for i, rows in tqdm(df.iterrows()):
    row_id = rows["Unnamed: 0"]
    row_save_path = save_path.format(id=row_id)
    if os.path.isfile(row_save_path):
        continue
    rows_values = rows[need_translated_columns].values
    translated_data = {col_name: None for col_name in translated_columns}
    
    #-- Translation
    for attempt in range(attempts):
        try:
            translated_rows = await row_translation(rows_values)
            for i, col_name in enumerate(need_translated_columns):
                trans_col_name = f"translated_{col_name}"
                translated_data[trans_col_name] = translated_rows[i]
                np.save(row_save_path, translated_data)
            break
        except Exception as e:
            print(f"ID: {row_id} - Try: {attempt}")
            print(e)
            time.sleep(2)
# Out:
# 3144it [00:02, 1366.98it/s]
# ID: 6458 - Try: 0
# Server disconnected without sending a response.
# 3250it [03:04,  2.58s/it]
# ID: 6374 - Try: 0
# 3435it [11:54,  3.00s/it]
# ID: 6180 - Try: 0
# 3444it [12:33,  3.84s/it]
# ID: 6165 - Try: 0
# 3448it [12:54,  4.14s/it]
# ID: 6164 - Try: 0
# 3693it [23:25,  2.41s/it]
# ID: 5886 - Try: 0
# 3715it [24:24,  2.47s/it]
# ID: 5862 - Try: 0
# 4195it [44:55,  2.55s/it]
# ID: 5328 - Try: 0
# 4217it [45:56,  2.48s/it]
# ID: 5308 - Try: 0
# 4235it [46:49,  2.49s/it]
# ID: 5286 - Try: 0
# 4378it [53:00,  2.47s/it]
# ID: 5133 - Try: 0
# 4381it [53:15,  3.64s/it]
# ID: 5130 - Try: 0
# 4424it [55:09,  2.52s/it]
# ID: 5077 - Try: 0
# 4490it [57:50,  2.59s/it]
# ID: 5001 - Try: 0
# 4535it [59:47,  2.31s/it]
# ID: 4956 - Try: 0
# 4567it [1:01:12,  2.36s/it]
# ID: 4924 - Try: 0
# <StreamReset stream_id:1, error_code:ErrorCodes.REFUSED_STREAM, remote_reset:True>
# 4593it [1:02:22,  3.36s/it]
# ID: 4888 - Try: 0
# 4690it [1:06:33,  2.60s/it]
# ID: 4780 - Try: 0
# 4764it [1:09:36,  2.14s/it]
# ID: 4707 - Try: 0
# 5016it [1:19:34,  2.29s/it]
# ID: 4417 - Try: 0
# 5276it [1:29:52,  2.44s/it]
# ID: 4131 - Try: 0
# 5347it [1:32:40,  1.04s/it]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[3], line 3, in gg_translate(sentence, from_lang, to_lang)
#       2 async with Translator() as translator:
# ----> 3     result = await translator.translate(sentence, src=from_lang, dest=to_lang)
#       4     return result
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\googletrans\client.py:286, in Translator.translate(self, text, dest, src, **kwargs)
#     285 origin = text
# --> 286 data, response = await self._translate(text, dest, src, kwargs)
#     288 # this code will be updated when the format is changed.
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\googletrans\client.py:128, in Translator._translate(self, text, dest, src, override)
#     127 url = urls.TRANSLATE.format(host=self._pick_service_url())
# --> 128 r = await self.client.get(url, params=params)
#     130 if r.status_code == 200:
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpx\_client.py:1768, in AsyncClient.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1763 """
#    1764 Send a `GET` request.
#    1765
#    1766 **Parameters**: See `httpx.request`.
#    1767 """
# -> 1768 return await self.request(
#    1769     "GET",
#    1770     url,
#    1771     params=params,
#    1772     headers=headers,
#    1773     cookies=cookies,
#    1774     auth=auth,
#    1775     follow_redirects=follow_redirects,
#    1776     timeout=timeout,
#    1777     extensions=extensions,
#    1778 )
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpx\_client.py:1540, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1527 request = self.build_request(
#    1528     method=method,
#    1529     url=url,
#    (...)
#    1538     extensions=extensions,
#    1539 )
# -> 1540 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpx\_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpx\_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpx\_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpx\_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpx\_transports\default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\http_proxy.py:343, in AsyncTunnelHTTPConnection.handle_async_request(self, request)
#     342         self._connected = True
# --> 343 return await self._connection.handle_async_request(request)
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\http2.py:187, in AsyncHTTP2Connection.handle_async_request(self, request)
#     185     raise LocalProtocolError(exc)  # pragma: nocover
# --> 187 raise exc
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\http2.py:150, in AsyncHTTP2Connection.handle_async_request(self, request)
#     147 async with Trace(
#     148     "receive_response_headers", logger, request, kwargs
#     149 ) as trace:
# --> 150     status, headers = await self._receive_response(
#     151         request=request, stream_id=stream_id
#     152     )
#     153     trace.return_value = (status, headers)
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\http2.py:294, in AsyncHTTP2Connection._receive_response(self, request, stream_id)
#     293 while True:
# --> 294     event = await self._receive_stream_event(request, stream_id)
#     295     if isinstance(event, h2.events.ResponseReceived):
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\http2.py:336, in AsyncHTTP2Connection._receive_stream_event(self, request, stream_id)
#     335 while not self._events.get(stream_id):
# --> 336     await self._receive_events(request, stream_id)
#     337 event = self._events[stream_id].pop(0)
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\http2.py:364, in AsyncHTTP2Connection._receive_events(self, request, stream_id)
#     363 if stream_id is None or not self._events.get(stream_id):
# --> 364     events = await self._read_incoming_data(request)
#     365     for event in events:
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_async\http2.py:441, in AsyncHTTP2Connection._read_incoming_data(self, request)
#     440 try:
# --> 441     data = await self._network_stream.read(self.READ_NUM_BYTES, timeout)
#     442     if data == b"":
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\httpcore\_backends\anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      34 try:
# ---> 35     return await self._stream.receive(max_bytes=max_bytes)
#      36 except anyio.EndOfStream:  # pragma: nocover
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\anyio\streams\tls.py:244, in TLSStream.receive(self, max_bytes)
#     243 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 244     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     245     if not data:
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\anyio\streams\tls.py:187, in TLSStream._call_sslobject_method(self, func, *args)
#     185         await self.transport_stream.send(self._write_bio.read())
# --> 187     data = await self.transport_stream.receive()
#     188 except EndOfStream:
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\site-packages\anyio\_backends\_asyncio.py:1292, in SocketStream.receive(self, max_bytes)
#    1291 self._transport.resume_reading()
# -> 1292 await self._protocol.read_event.wait()
#    1293 self._transport.pause_reading()
#
# File c:\Users\RGA6HC\.conda\envs\emiu_venv\lib\asyncio\locks.py:214, in Event.wait(self)
#     213 try:
# --> 214     await fut
#     215     return True
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[10], line 15
#      13 for attempt in range(attempts):
#      14     try:
# ---> 15         translated_rows = await row_translation(rows_values)
#      16         for i, col_name in enumerate(need_translated_columns):
#      17             trans_col_name = f"translated_{col_name}"
#
# Cell In[4], line 3, in row_translation(row_sentences, from_lang, to_lang)
#       1 async def row_translation(row_sentences, from_lang="vi", to_lang="en"):
#       2     tasks = [run_gg_translate(sen) for sen in row_sentences]
# ----> 3     translated_sentences = await asyncio.gather(*tasks)
#       4     return translated_sentences
#
# CancelledError:
