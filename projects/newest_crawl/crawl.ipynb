# %% [markdown]
# # IMPORT

# %%
# from playwright_crawl import PlaywrightScrolling

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
url_template = "https://www.investing.com/equities/nvidia-corp-news/{page_id}"
url = url_template.format(page_id=1)
url = "https://vn.investing.com/indices/vn-news/2"

hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(url, headers=hdr)
res = urlopen(req)

# %%
html = res.read().decode('utf-8')

# %% [markdown]
# # TEST PARSE

# %%
def parse_thumnail_details_in_source(source_content):
    source_soup = BeautifulSoup(source_content)
    all_news_html = source_soup.find_all("div", class_="block w-full sm:flex-1")
    all_news_items = []
    for new_html in tqdm(all_news_html):
        item_title_html = new_html.find("a", class_="block text-base font-bold leading-5 hover:underline sm:text-base sm:leading-6 md:text-lg md:leading-7")
        item_url = item_title_html.get("href", "")
        title = item_title_html.text
        item_posted_time = new_html.find("li", class_="ml-2").text
        
        #-- preprocessing
        if "•" in item_posted_time:
            item_posted_time = item_posted_time.replace("•", "")
        
        #-- set variables
        item = {
            "item_url": item_url.strip(), 
            "title": title.strip(),
            "time": item_posted_time.strip(),
        }
        all_news_items.append(item)
    return all_news_items

# %%
parse_thumnail_details_in_source(html)
# html
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 9027.77it/s]
# [{'item_url': 'https://vn.investing.com/news/stock-market-news/goc-nhin-2101-uu-tien-su-than-trong-2515113',
#   'title': 'Góc nhìn 21/01: Ưu tiên sự thận trọng',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/vietstock-daily-21012026-rung-lac-con-tiep-dien-2514984',
#   'title': 'Vietstock Daily 21/01/2026: Rung lắc còn tiếp diễn?',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/noi-long-nguoi-trong-cuoc-vao-nam-kho-kiem-tien-nhat-san-chung-khoan-2514707',
#   'title': 'Nỗi lòng người trong cuộc vào năm ’khó kiếm tiền nhất’ sàn chứng khoán',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/nhip-dap-thi-truong-2001-su-phan-hoa-lan-rong-2514676',
#   'title': 'Nhịp đập Thị trường 20/01: Sự phân hóa lan rộng',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/phan-tich-ky-thuat-phien-chieu-2001-giang-co-ngan-han-2514675',
#   'title': 'Phân tích kỹ thuật phiên chiều 20/01: Giằng co ngắn hạn',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/mot-chu-ky-thanh-khoan-moi-dang-mo-ra-cho-thi-truong-viet-nam-2514657',
#   'title': 'Một chu kỳ thanh khoản mới đang mở ra cho thị trường Việt Nam',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/vietstock-live-22-goc-nhin-dau-tu-2026--don-dau-tang-truong-hai-con-so-hay-hoa-giai-rui-ro-an-so-2514652',
#   'title': 'Vietstock LIVE #22: Góc nhìn đầu tư 2026 – Đón đầu tăng trưởng hai con số hay hóa giải rủi ro “ẩn số”?',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/mbs-vnindex-tiem-can-1900-diem-rui-ro-rung-lac-gia-tang-2514625',
#   'title': 'MBS: VN-Index tiệm cận 1.900 điểm, rủi ro rung lắc gia tăng',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/2001-doc-gi-truoc-gio-giao-dich-chung-khoan-2514598',
#   'title': '20/01: Đọc gì trước giờ giao dịch chứng khoán?',
#   'time': '20 thg 1, 2026'},
#  {'item_url': 'https://vn.investing.com/news/stock-market-news/thanh-khoan-bung-no-dong-tien-chay-vao-co-phieu-chung-khoan-2514553',
#   'title': 'Thanh khoản bùng nổ, dòng tiền chảy vào cổ phiếu chứng khoán',
#   'time': '19 thg 1, 2026'}]

# %%
source_soup = BeautifulSoup(html)
all_news_html = source_soup.find_all("div", class_="block w-full sm:flex-1")
item_title_html = all_news_html[0].find("a", class_="block text-base font-bold leading-5 hover:underline sm:text-base sm:leading-6 md:text-lg md:leading-7")
item_url = item_title_html.get("href", "")
title = item_title_html.text

# %%
item_url
title
# Out:
# 'Góc nhìn 21/01: Ưu tiên sự thận trọng'
