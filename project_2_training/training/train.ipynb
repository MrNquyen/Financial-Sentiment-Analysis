# %% [markdown]
# # IMPORT

# %%
import os
import re
import json
import joblib
import asyncio
import pandas as pd
import numpy as np

from tqdm import tqdm
from transformers import pipeline

from sklearn import metrics
from collections import Counter
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.metrics import f1_score, accuracy_score

# %% [markdown]
# # LOAD DATA

# %%
data_save_dir = r"F:\UNIVERSITY\Project\Sentiment-Analysis-Airflow\Financial-Sentiment-Analysis\project_2_training\data"
train_path = os.path.join(data_save_dir, "train.csv")
test_path = os.path.join(data_save_dir, "test.csv")

# %%
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %%
X_train, y_train = train_df["title"].values, train_df["label"].values
X_test, y_test = test_df["title"].values, test_df["label"].values

# %% [markdown]
# # FEATURES EXTRACTION

# %%
vectorizer = TfidfVectorizer()
X_train_transform = vectorizer.fit_transform(X_train)
X_test_transform = vectorizer.transform(X_test)

# %% [markdown]
# # TRAINING

# %%
def training(param_grid, model_class, X_train, y_train):
    model_search = RandomizedSearchCV(
        model_class(),
        param_grid
    )
    model_search.fit(X_train, y_train)
    best_model = model_search.best_estimator_
    return best_model

# %%
save_dir = r"F:\UNIVERSITY\Project\Sentiment-Analysis-Airflow\Financial-Sentiment-Analysis\project_2_training\predictions"

# %% [markdown]
# # *Random Forest*

# %%
rf_param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20, 30, 40, 50],    
    'min_samples_split': [2, 5],
    'max_features': ["sqrt", "log2"],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True, False]
}

rf_best_model = training(
    param_grid=rf_param_grid, 
    model_class=RandomForestClassifier,
    X_train=X_train_transform,
    y_train=y_train,
)

# %%
rf_pred = rf_best_model.predict(X_test_transform)
np.save(os.path.join(save_dir, "rf_prediction.npy"), rf_pred)

# %% [markdown]
# # *SVC*

# %%
# Thiết lập lưới tham số phù hợp với cơ chế của SVM
svc_param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'poly'], 
    'gamma': ['scale', 'auto', 0.1, 0.01], 
    'degree': [2, 3],
    'probability': [True]
}

svc_best_model = training(
    param_grid=svc_param_grid, 
    model_class=SVC,
    X_train=X_train_transform,
    y_train=y_train,
)

# %%
svc_pred = svc_best_model.predict(X_test_transform)
np.save(os.path.join(save_dir, "svc_prediction.npy"), svc_pred)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
lr_param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l2'],
    'solver': ['lbfgs', 'saga'],
    'max_iter': [1000]
}

lr_best_model = training(
    param_grid=lr_param_grid, 
    model_class=LogisticRegression,
    X_train=X_train_transform,
    y_train=y_train,
)

# %%
lr_pred = lr_best_model.predict(X_test_transform)
np.save(os.path.join(save_dir, "lr_prediction.npy"), lr_pred)

# %%
save_dir
# Out:
# 'F:\\UNIVERSITY\\Project\\Sentiment-Analysis-Airflow\\Financial-Sentiment-Analysis\\project_2_training\\predictions'

# %% [markdown]
# # *KNN*

# %%
knn_param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan'],
    'leaf_size': [20, 30, 40]
}

# 2. Huấn luyện mô hình
knn_best_model = training(
    param_grid=knn_param_grid, 
    model_class=KNeighborsClassifier,
    X_train=X_train_transform,
    y_train=y_train,
)

# %%
knn_pred = knn_best_model.predict(X_test_transform)
np.save(os.path.join(save_dir, "knn_prediction.npy"), knn_pred)

# %% [markdown]
# ## *Save Model*

# %%
# model_save_dir = r"F:\UNIVERSITY\Project\Sentiment-Analysis-Airflow\Financial-Sentiment-Analysis\project_2_training\save"
model_save_dir = r"C:\APAC\all_projects\finetuning-airflow-project\project_2_training\save"
os.makedirs(model_save_dir, exist_ok=True)

# Save the model
rf_model_path = os.path.join(model_save_dir, "rf_model.pkl")
svc_model_path = os.path.join(model_save_dir, "svc_model.pkl")
knn_model_path = os.path.join(model_save_dir, "knn_model.pkl")
lr_model_path = os.path.join(model_save_dir, "lr_model.pkl")
tfidf_path = os.path.join(model_save_dir, "tfidf.pkl")

joblib.dump(rf_best_model, rf_model_path)
joblib.dump(svc_best_model, svc_model_path)
joblib.dump(knn_best_model, knn_model_path)
joblib.dump(lr_best_model, lr_model_path)
joblib.dump(vectorizer, tfidf_path)

# print(f"Model saved to: {model_path}")
print(f"TFIDF saved to: {tfidf_path}")
# Out:
# TFIDF saved to: C:\APAC\all_projects\finetuning-airflow-project\project_2_training\save\tfidf.pkl
