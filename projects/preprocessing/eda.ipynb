# %% [markdown]
# # IMPORT

# %%
import os
import pandas as pd

# %% [markdown]
# # LOAD DATA

# %%
path = r"C:\APAC\all_projects\finetuning-airflow-project\projects\data\sentiment_finance_news_with_scores.csv"
df = pd.read_csv(path)

# %% [markdown]
# # EDA

# %%
posted_date_col = df["posted_date"]

# %%
posted_date_col.min(), posted_date_col.max()
# Out:
# ('2021-12-01 23:52:00', '2026-01-22 06:57:00')
