# %% [markdown]
# # IMPORT

# %%
import os
import bs4
import json
import requests

# %% [markdown]
# # CRAWL

# %%
def request_html(url):
    response = requests.get(url)
    return response

# %%
url_template = "https://www.investing.com/equities/nvidia-corp-news/{page_id}"
url = url_template.format(page_id=1)
response = request_html(url)

# %%
url
# Out:
# 'https://www.investing.com/equities/nvidia-corp-news/1'

# %%
response.status_code
# Out:
# 403
