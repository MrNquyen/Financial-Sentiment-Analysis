# %%
import numpy as np

# %%
path = r"C:\APAC\all_projects\finetuning-airflow-project\projects\data\save_translation\9954.npy"
np.load(path, allow_pickle=True)
# Out:
# array({'translated_relative_sen_0': 'After previous days of strong falls, market indexes simultaneously rebounded strongly in the trading session on December 7, 2021.', 'translated_relative_sen_1': 'The utility stocks group is temporarily trading very actively and is one of the fastest growing sectors in the market', 'translated_relative_sen_2': 'With the\xa0hnx-index, the purple color of idc hn:idc also helped the index recover positively in this morning session', 'translated_relative_sen_3': 'The positivity covers almost all indexes of industry groups except for the service, accommodation, food and entertainment industry with a slight red color below the reference.', 'translated_relative_sen_4': 'Utilities are the industry with the strongest growth in the market with an increase of 3'},
#       dtype=object)
